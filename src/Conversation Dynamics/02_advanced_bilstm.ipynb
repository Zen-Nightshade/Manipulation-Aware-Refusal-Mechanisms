# %%
import re
import ast
import numpy as np
import pandas as pd
from pathlib import Path

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from transformers import AutoModel

from collections import Counter

from sklearn.model_selection import train_test_split

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
CON = Path("/kaggle/input/datasets/zennightshade/intent5/preprocessed/mentalmanip_con.csv")
MAJ = Path("/kaggle/input/datasets/zennightshade/intent5/preprocessed/mentalmanip_maj.csv")

# %%
class Vocab:
    def __init__(self, min_freq=2):
        self.min_freq = min_freq
        self.word2idx = {
            "<pad>": 0,
            "<unk>": 1,
            "<p1>": 2,
            "<p2>": 3
        }
        self.idx2word = {v: k for k, v in self.word2idx.items()}

    def normalize(self, text):
        text = text.lower()

        text = re.sub(r"n't", " n't", text)
        text = re.sub(r"'re", " 're", text)
        text = re.sub(r"'s", " 's", text)
        text = re.sub(r"'ll", " 'll", text)

        return text

    def tokenize(self, text):
        text = self.normalize(text)

        text = re.sub(r"([!?.,])", r" \1 ", text)

        text = re.sub(r"\s+", " ", text).strip()

        return text.split()

    def build(self, texts):
        counter = Counter()

        for text in texts:
            tokens = self.tokenize(text)
            counter.update(tokens)

        for word, freq in counter.items():
            if freq >= self.min_freq and word not in self.word2idx:
                idx = len(self.word2idx)
                self.word2idx[word] = idx
                self.idx2word[idx] = word

    def encode(self, text, speaker=None):
        tokens = self.tokenize(text)

        if speaker == 1:
            tokens = ["<p1>"] + tokens
        elif speaker == 2:
            tokens = ["<p2>"] + tokens

        return [self.word2idx.get(t, 1) for t in tokens]

# %%
def parse_dialogue_with_speakers(dialogue):
    pattern = r'(Person\d+):'
    splits = re.split(pattern, dialogue)

    turns = []
    for i in range(1, len(splits), 2):
        speaker = splits[i]
        text = splits[i+1].strip()

        speaker_id = 1 if "1" in speaker else 2
        turns.append((speaker_id, text))

    return turns


def build_transitions(turns):
    pairs = []
    for i in range(1, len(turns)):
        pairs.append((turns[i-1], turns[i]))
    return pairs

class ConversationDataset(Dataset):
    def __init__(self, df, vocab, max_len=50, max_turns=10):
        self.samples = []
        self.vocab = vocab
        self.max_len = max_len
        self.max_turns = max_turns

        for _, row in df.iterrows():
            turns = parse_dialogue_with_speakers(row["Dialogue"])

            if len(turns) < 2:
                continue

            encoded_turns = []

            for s, text in turns[:max_turns]:
                enc = vocab.encode(text, speaker=s)
                enc = enc[:max_len] + [0] * max(0, max_len - len(enc))
                encoded_turns.append(enc)

            self.samples.append((encoded_turns, row["label"]))

    def __getitem__(self, idx):
        turns, label = self.samples[idx]

        return {
            "turns": torch.tensor(turns, dtype=torch.long),  # (T, L)
            "length": len(turns),
            "label": torch.tensor(label, dtype=torch.float)
        }

    def __len__(self):
        return len(self.samples)

# %%
def collate_fn(batch):
    batch_size = len(batch)

    max_turns = max(item["turns"].shape[0] for item in batch)
    max_len = batch[0]["turns"].shape[1]

    turns_batch = torch.zeros((batch_size, max_turns, max_len), dtype=torch.long)
    mask = torch.zeros((batch_size, max_turns), dtype=torch.float)

    labels = []

    for i, item in enumerate(batch):
        t = item["turns"]
        length = t.shape[0]

        turns_batch[i, :length] = t
        mask[i, :length] = 1

        labels.append(item["label"])

    return {
        "turns": turns_batch,   # (B, T, L)
        "mask": mask,           # (B, T)
        "label": torch.stack(labels)
    }

# %%
class Model1(nn.Module):
    def __init__(self, vocab_size, embed_dim=128, hidden_dim=128, num_labels=12):
        super().__init__()
        self.embedding = nn.Embedding(vocab_size, embed_dim, padding_idx=0)
        
        self.turn_encoder = nn.LSTM(embed_dim, hidden_dim, batch_first=True, bidirectional=True)
        
        self.classifier = nn.Sequential(
            nn.Linear(hidden_dim * 2, 256),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(256, num_labels)
        )
        self.register_buffer("thresholds", torch.full((num_labels,), 0.5))

    def encode_turn(self, x):
        emb = self.embedding(x)
        out, _ = self.turn_encoder(emb)
        return out.mean(dim=1)  # (B*T, 2H)

    def forward(self, batch):
        turns, mask = batch["turns"], batch["mask"]
        B, T, L = turns.shape

        h = self.encode_turn(turns.reshape(B * T, L)).reshape(B, T, -1) # (B, T, 2H)
        mask_t = mask.unsqueeze(-1).float() # (B, T, 1)
        sum_h = torch.sum(h * mask_t, dim=1)
        active_turns = torch.clamp(mask_t.sum(dim=1), min=1.0)
        mean_conversation = sum_h / active_turns # (B, 2H)

        return self.classifier(mean_conversation)

    # -------- Inference (Same for all models) --------
    def predict_proba(self, batch): return torch.sigmoid(self.forward(batch))
    def predict(self, batch): return (self.predict_proba(batch) > self.thresholds.to(batch["turns"].device)).int()
    def set_thresholds(self, t): self.thresholds = torch.tensor(t, dtype=torch.float, device=self.thresholds.device)

# %%
class Model2(nn.Module):
    def __init__(self, vocab_size, embed_dim=128, hidden_dim=128, num_labels=12):
        super().__init__()
        self.embedding = nn.Embedding(vocab_size, embed_dim, padding_idx=0)
        
        self.turn_encoder = nn.LSTM(embed_dim, hidden_dim, batch_first=True, bidirectional=True)
        
        self.classifier = nn.Sequential(
            nn.Linear(hidden_dim * 4, 256),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(256, num_labels)
        )
        self.register_buffer("thresholds", torch.full((num_labels,), 0.5))

    def encode_turn(self, x):
        emb = self.embedding(x)
        out, _ = self.turn_encoder(emb)
        return out.mean(dim=1)  # (B*T, 2H)

    def forward(self, batch):
        turns, mask = batch["turns"], batch["mask"]
        B, T, L = turns.shape

        h = self.encode_turn(turns.reshape(B * T, L)).reshape(B, T, -1) # (B, T, 2H)

        mask_t = mask.unsqueeze(-1)
        
        sum_h = torch.sum(h * mask_t, dim=1)
        active_turns = torch.clamp(mask_t.sum(dim=1), min=1.0)
        mean_conv = sum_h / active_turns # (B, 2H)

        h_masked = h.masked_fill(mask_t == 0, -1e4)
        max_conv, _ = torch.max(h_masked, dim=1) # (B, 2H)

        combined_conv = torch.cat([mean_conv, max_conv], dim=-1) # (B, 4H)
        
        return self.classifier(combined_conv)

    # -------- Inference (Same for all models) --------
    def predict_proba(self, batch): return torch.sigmoid(self.forward(batch))
    def predict(self, batch): return (self.predict_proba(batch) > self.thresholds.to(batch["turns"].device)).int()
    def set_thresholds(self, t): self.thresholds = torch.tensor(t, dtype=torch.float, device=self.thresholds.device)

# %%
class Model3(nn.Module):
    def __init__(self, vocab_size, embed_dim=128, hidden_dim=128, num_labels=12):
        super().__init__()
        self.embedding = nn.Embedding(vocab_size, embed_dim, padding_idx=0)
        
        self.turn_encoder = nn.LSTM(embed_dim, hidden_dim, batch_first=True, bidirectional=True)
        
        self.attention = nn.Sequential(
            nn.Linear(hidden_dim * 2, hidden_dim),
            nn.Tanh(),
            nn.Linear(hidden_dim, 1)
        )
        
        self.classifier = nn.Sequential(
            nn.Linear(hidden_dim * 2, 256),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(256, num_labels)
        )
        self.register_buffer("thresholds", torch.full((num_labels,), 0.5))

    def encode_turn(self, x):
        emb = self.embedding(x)
        out, _ = self.turn_encoder(emb)
        return out.mean(dim=1)  # (B*T, 2H)

    def forward(self, batch):
        turns, mask = batch["turns"], batch["mask"]
        B, T, L = turns.shape

        h = self.encode_turn(turns.reshape(B * T, L)).reshape(B, T, -1) # (B, T, 2H)

        attention_scores = self.attention(h).squeeze(-1) # (B, T)
        
        attention_scores = attention_scores.masked_fill(mask == 0, -1e9)
        
        attention_weights = torch.softmax(attention_scores, dim=1).unsqueeze(-1) # (B, T, 1)
        
        attention_conversation = torch.sum(h * attention_weights, dim=1) # (B, 2H)

        return self.classifier(attention_conversation)

    # -------- Inference (Same for all models) --------
    def predict_proba(self, batch): return torch.sigmoid(self.forward(batch))
    def predict(self, batch): return (self.predict_proba(batch) > self.thresholds.to(batch["turns"].device)).int()
    def set_thresholds(self, t): self.thresholds = torch.tensor(t, dtype=torch.float, device=self.thresholds.device)

# %%
class Model4(nn.Module):
    def __init__(self, vocab_size, embed_dim=128, hidden_dim=128, num_labels=12):
        super().__init__()
        self.embedding = nn.Embedding(vocab_size, embed_dim, padding_idx=0)
        
        self.turn_encoder = nn.LSTM(embed_dim, hidden_dim, batch_first=True, bidirectional=True)
        
        self.dialogue_encoder = nn.LSTM(hidden_dim * 2, hidden_dim, batch_first=True, bidirectional=True)
        
        self.classifier = nn.Sequential(
            nn.Linear(hidden_dim * 2, 256),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(256, num_labels)
        )
        self.register_buffer("thresholds", torch.full((num_labels,), 0.5))

    def encode_turn(self, x):
        emb = self.embedding(x)
        out, _ = self.turn_encoder(emb)
        return out.mean(dim=1)

    def forward(self, batch):
        turns, mask = batch["turns"], batch["mask"]
        B, T, L = turns.shape

        h = self.encode_turn(turns.reshape(B * T, L)).reshape(B, T, -1) # (B, T, 2H)

        out, (h_n, _) = self.dialogue_encoder(h)
        
        global_repr = torch.cat([h_n[-2], h_n[-1]], dim=1) # (B, 2H)

        return self.classifier(global_repr)

    # -------- Inference --------
    def predict_proba(self, batch): return torch.sigmoid(self.forward(batch))
    def predict(self, batch): return (self.predict_proba(batch) > self.thresholds.to(batch["turns"].device)).int()
    def set_thresholds(self, t): self.thresholds = torch.tensor(t, dtype=torch.float, device=self.thresholds.device)

# %%
class Model5(nn.Module):
    def __init__(self, vocab_size, embed_dim=128, hidden_dim=128, num_labels=12):
        super().__init__()

        self.hidden_dim = hidden_dim

        self.embedding = nn.Embedding(vocab_size, embed_dim, padding_idx=0)

        self.turn_encoder = nn.LSTM(
            embed_dim,
            hidden_dim,
            batch_first=True,
            bidirectional=True
        )

        self.transition_encoder = nn.LSTM(
            hidden_dim * 4,
            hidden_dim,
            batch_first=True,
            bidirectional=True
        )

        self.classifier = nn.Sequential(
            nn.Linear(hidden_dim * 4, 256),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(256, num_labels)
        )

        self.register_buffer("thresholds", torch.full((num_labels,), 0.5))

    def encode_turn(self, x):
        emb = self.embedding(x)

        out, _ = self.turn_encoder(emb)
        h = out.mean(dim=1)

        return h  # (B, 2H)

    def forward(self, batch):
        turns = batch["turns"]   # (B, T, L)
        mask = batch["mask"]     # (B, T)

        B, T, L = turns.shape

        turns = turns.reshape(B * T, L)

        h = self.encode_turn(turns)   # (B*T, 2H)
        h = h.reshape(B, T, -1)       # (B, T, 2H)

        # transitions
        diff = h[:, 1:, :] - h[:, :-1, :]
        prod = h[:, 1:, :] * h[:, :-1, :]

        delta = torch.cat([diff, prod], dim=-1)  # (B, T-1, 4H)

        out, (h_n, _) = self.transition_encoder(delta)

        # global summary
        global_repr = torch.cat([h_n[-2], h_n[-1]], dim=1)  # (B, 2H)
        
        # local strongest transition
        mask_t = mask[:, 1:].unsqueeze(-1)  # (B, T-1, 1)
        out_masked = out.masked_fill(mask_t == 0, -1e9)
        
        local_repr, _ = torch.max(out_masked, dim=1)  # (B, 2H)
        
        final_repr = torch.cat([global_repr, local_repr], dim=1)  # (B, 4H)
        
        logits = self.classifier(final_repr)

        return logits

    # -------- Inference --------
    def predict_proba(self, batch):
        logits = self.forward(batch)
        return torch.sigmoid(logits)

    def predict(self, batch):
        probs = self.predict_proba(batch)
        return (probs > self.thresholds.to(probs.device)).int()

    def set_thresholds(self, thresholds):
        self.thresholds = torch.tensor(
            thresholds,
            dtype=torch.float,
            device=self.thresholds.device
        )

# %%
def evaluate(model, loader, device, name="Eval"):
    model.eval()

    preds, labels = [], []

    with torch.no_grad():
        for batch in loader:
            batch = {k: v.to(device) for k, v in batch.items()}

            pred = model.predict(batch).cpu().numpy()
            label = batch["label"].cpu().numpy()

            preds.append(pred)
            labels.append(label)

    preds = np.vstack(preds)
    labels = np.vstack(labels)

    print(f"\n{name} Metrics:")
    print("F1 (macro):", f1_score(labels, preds, average="macro", zero_division=0))
    print("F1 (micro):", f1_score(labels, preds, average="micro", zero_division=0))
    print(f"Thresholds: {model.thresholds}")

# %%
def tune_thresholds(model, loader, device):
    model.eval()
    all_probs, all_labels = [], []

    with torch.no_grad():
        for batch in loader:
            batch = {k: v.to(device) for k, v in batch.items()}

            probs = model.predict_proba(batch).cpu().numpy()
            labels = batch["label"].cpu().numpy()

            all_probs.append(probs)
            all_labels.append(labels)

    all_probs = np.vstack(all_probs)
    all_labels = np.vstack(all_labels)

    thresholds = []

    for i in range(all_labels.shape[1]):
        best_t, best_f1 = 0.5, 0

        for t in np.linspace(0.05, 0.9, 18):
            preds = (all_probs[:, i] > t).astype(int)
            f1 = f1_score(all_labels[:, i], preds, zero_division=0)

            if f1 > best_f1:
                best_f1 = f1
                best_t = t
            # print(f"Class {i} - Best F1: {best_f1}")

        thresholds.append(best_t)

    model.set_thresholds(thresholds)

# %%
def train(model, train_loader, val_loader, lr, pos_weight, device, epochs=20):

    model.to(device)

    optimizer = torch.optim.Adam(model.parameters(), lr=lr)

    criterion = nn.BCEWithLogitsLoss(pos_weight=pos_weight.to(device))

    for epoch in range(epochs):
        model.train()
        total_loss = 0

        for batch in train_loader:
            batch = {k: v.to(device) for k, v in batch.items()}
            logits = model(batch)
            loss = criterion(logits, batch["label"])

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            total_loss += loss.item()

        print(f"\nEpoch {epoch+1} Loss: {total_loss / len(train_loader):.4f}")

        # print("yo")
        tune_thresholds(model, val_loader, device)
        # print("yo2")

        evaluate(model, val_loader, device, name=f"Val Epoch {epoch+1}")

# %%
def get_stratify_key(label):
    count = sum(label)

    if count == 0:
        return "none"
    elif count == 1:
        return "single"
    else:
        return "multi"

# %%
def load_dataframe(path):
    df = pd.read_csv(path)

    # convert string -> list
    df["label"] = df["label"].apply(lambda x: ast.literal_eval(x))

    return df

df = load_dataframe(CON)

def get_stratify_key(label):
    count = sum(label)

    if count == 0:
        return "none"
    elif count == 1:
        return "single"
    else:
        return "multi"

def check_distribution(df, name):
    labels = np.vstack(df["label"].values)
    print(f"\n{name}")
    print("Pos:", labels.sum(axis=0))

check_distribution(df, "before split")

df["stratify_key"] = df["label"].apply(get_stratify_key)

from sklearn.model_selection import train_test_split

train_df, val_test_df = train_test_split(
    df,
    test_size=0.2,
    random_state=42,
    stratify=df["stratify_key"]
)

val_df, test_df = train_test_split(
    val_test_df,
    test_size=0.5,
    random_state=42,
    stratify=val_test_df["stratify_key"]
)


check_distribution(train_df, "Train")
check_distribution(val_df, "Val")
check_distribution(test_df, "Test")
# Out:
# before split
# Pos: [ 87  83  58 213  69  30 384 321 133 361 607 899]
#
# Train
# Pos: [ 70  64  51 165  49  23 312 263 108 289 482 720]
#
# Val
# Pos: [ 8  9  6 24  9  3 37 27 13 32 59 96]
#
# Test
# Pos: [ 9 10  1 24 11  4 35 31 12 40 66 83]

# %%
all_turns = []

for dialogue in train_df["Dialogue"]:
    turns = parse_dialogue_with_speakers(dialogue)
    for _, text in turns:
        all_turns.append(text)

vocab = Vocab(min_freq=2)
vocab.build(all_turns)

print("Vocab size:", len(vocab.word2idx))
# Out:
# Vocab size: 5659

# %%
lengths = []

for d in df["Dialogue"]:
    turns = parse_dialogue_with_speakers(d)
    for _, text in turns:
        lengths.append(len(vocab.encode(text)))

print("Mean:", np.mean(lengths))
print("95th percentile:", np.percentile(lengths, 95))
print("Max:", np.max(lengths))
# Out:
# Mean: 16.951578337677383
# 95th percentile: 49.0
# Max: 398

# %%
train_dataset = ConversationDataset(train_df, vocab)
val_dataset = ConversationDataset(val_df, vocab)
test_dataset = ConversationDataset(test_df, vocab)


train_loader = DataLoader(
    train_dataset,
    batch_size=32,
    shuffle=True,
    collate_fn=collate_fn  # THIS is mandatory
)

val_loader = DataLoader(
    val_dataset,
    batch_size=32,
    shuffle=False,
    collate_fn=collate_fn
)

test_loader = DataLoader(
    test_dataset,
    batch_size=32,
    shuffle=False,
    collate_fn=collate_fn
)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
labels = np.vstack(train_df["label"].values)

pos_counts = labels.sum(axis=0)
neg_counts = len(labels) - pos_counts

pos_weight = torch.tensor((neg_counts / (pos_counts + 1e-5)), dtype=torch.float).to(device)
print(pos_weight)
# Out:
# tensor([29.2429, 32.0781, 40.5098, 11.8303, 42.2041, 91.0434,  5.7853,  7.0494,
#         18.6019,  6.3253,  3.3921,  1.9403], device='cuda:0')

# %%
model1 = Model1(
    vocab_size=len(vocab.word2idx),
    embed_dim= 256,
    hidden_dim= 256,
    num_labels= 12
)

model1.to(device)

train(
    model= model1, 
    train_loader= train_loader, 
    val_loader= val_loader, 
    lr= 2e-3,
    pos_weight= pos_weight, 
    epochs= 12,
    device= device
)
# Out:
# Epoch 1 Loss: 1.2410
#
# Val Epoch 1 Metrics:
# F1 (macro): 0.20430564068404547
# F1 (micro): 0.23357664233576642
# Thresholds: tensor([0.4500, 0.4500, 0.4500, 0.5000, 0.4500, 0.4500, 0.4500, 0.5000, 0.4500,
#         0.4500, 0.5000, 0.0500], device='cuda:0')
#
# Epoch 2 Loss: 1.2244
#
# Val Epoch 2 Metrics:
# F1 (macro): 0.2442415086465887
# F1 (micro): 0.29431438127090304
# Thresholds: tensor([0.5500, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.4500, 0.5500,
#         0.5000, 0.5000, 0.0500], device='cuda:0')
#
# Epoch 3 Loss: 1.1031
#
# Val Epoch 3 Metrics:
# F1 (macro): 0.2968523334528101
# F1 (micro): 0.3553299492385787
# Thresholds: tensor([0.5000, 0.5000, 0.3500, 0.3500, 0.7000, 0.7000, 0.5500, 0.5500, 0.5500,
#         0.5000, 0.6000, 0.4000], device='cuda:0')
#
# Epoch 4 Loss: 0.9201
#
# Val Epoch 4 Metrics:
# F1 (macro): 0.3046223429594326
# F1 (micro): 0.3767634854771784
# Thresholds: tensor([0.6500, 0.7000, 0.5500, 0.4500, 0.9000, 0.9000, 0.4500, 0.5500, 0.7500,
#         0.5500, 0.5000, 0.2000], device='cuda:0')
#
# Epoch 5 Loss: 0.7792
#
# Val Epoch 5 Metrics:
# F1 (macro): 0.29920667246799265
# F1 (micro): 0.3834652594547054
# Thresholds: tensor([0.9000, 0.7000, 0.2000, 0.5000, 0.4500, 0.2500, 0.5000, 0.5000, 0.7000,
#         0.7000, 0.3500, 0.3000], device='cuda:0')
#
# Epoch 6 Loss: 0.6383
#
# Val Epoch 6 Metrics:
# F1 (macro): 0.3017356048513819
# F1 (micro): 0.3645655877342419
# Thresholds: tensor([0.9000, 0.8000, 0.3000, 0.3500, 0.2500, 0.0500, 0.5000, 0.3000, 0.4500,
#         0.5000, 0.4000, 0.4500], device='cuda:0')
#
# Epoch 7 Loss: 0.5351
#
# Val Epoch 7 Metrics:
# F1 (macro): 0.3210783048825035
# F1 (micro): 0.37037037037037035
# Thresholds: tensor([0.7000, 0.5500, 0.7500, 0.1500, 0.1500, 0.1000, 0.7000, 0.4500, 0.4500,
#         0.4000, 0.4500, 0.3500], device='cuda:0')
#
# Epoch 8 Loss: 0.4347
#
# Val Epoch 8 Metrics:
# F1 (macro): 0.28778692628563685
# F1 (micro): 0.3805668016194332
# Thresholds: tensor([0.9000, 0.5500, 0.3500, 0.0500, 0.5000, 0.5000, 0.7500, 0.5000, 0.2000,
#         0.6000, 0.3500, 0.4000], device='cuda:0')
#
# Epoch 9 Loss: 0.3648
#
# Val Epoch 9 Metrics:
# F1 (macro): 0.2658162762601346
# F1 (micro): 0.38057482656095143
# Thresholds: tensor([0.7000, 0.1000, 0.5000, 0.2000, 0.5000, 0.5000, 0.7500, 0.1000, 0.1000,
#         0.6000, 0.3500, 0.1000], device='cuda:0')
#
# Epoch 10 Loss: 0.3091
#
# Val Epoch 10 Metrics:
# F1 (macro): 0.2935951398829243
# F1 (micro): 0.39068825910931176
# Thresholds: tensor([0.7500, 0.3000, 0.8500, 0.0500, 0.2000, 0.5000, 0.6500, 0.5000, 0.5000,
#         0.3500, 0.4500, 0.1000], device='cuda:0')
#
# Epoch 11 Loss: 0.2650
#
# Val Epoch 11 Metrics:
# F1 (macro): 0.300712263789148
# F1 (micro): 0.3858520900321543
# Thresholds: tensor([0.9000, 0.5500, 0.8000, 0.4500, 0.0500, 0.1500, 0.4500, 0.5500, 0.4000,
#         0.1500, 0.4500, 0.0500], device='cuda:0')
#
# Epoch 12 Loss: 0.2322
#
# Val Epoch 12 Metrics:
# F1 (macro): 0.28544856115688216
# F1 (micro): 0.3845223700120919
# Thresholds: tensor([0.8000, 0.4500, 0.7000, 0.4500, 0.1500, 0.5000, 0.4500, 0.1000, 0.1500,
#         0.3000, 0.3000, 0.5000], device='cuda:0')

# %%
model2 = Model2(
    vocab_size=len(vocab.word2idx),
    embed_dim= 256,
    hidden_dim= 128,
    num_labels= 12
)

model2.to(device)

train(
    model= model2, 
    train_loader= train_loader, 
    val_loader= val_loader, 
    lr= 3e-3,
    pos_weight= pos_weight, 
    epochs= 12,
    device= device
)
# Out:
# Epoch 1 Loss: 1.2599
#
# Val Epoch 1 Metrics:
# F1 (macro): 0.20116930390693222
# F1 (micro): 0.2299115724721261
# Thresholds: tensor([0.4500, 0.5000, 0.5000, 0.0500, 0.5500, 0.3500, 0.4500, 0.4500, 0.5000,
#         0.5000, 0.0500, 0.4500], device='cuda:0')
#
# Epoch 2 Loss: 1.1873
#
# Val Epoch 2 Metrics:
# F1 (macro): 0.2742652077173577
# F1 (micro): 0.3511214230471771
# Thresholds: tensor([0.6500, 0.6500, 0.6000, 0.4000, 0.8000, 0.5500, 0.5000, 0.4500, 0.7500,
#         0.6000, 0.4000, 0.4000], device='cuda:0')
#
# Epoch 3 Loss: 0.9839
#
# Val Epoch 3 Metrics:
# F1 (macro): 0.3246794134590362
# F1 (micro): 0.3660130718954248
# Thresholds: tensor([0.8500, 0.7000, 0.7500, 0.2000, 0.7500, 0.5500, 0.5000, 0.5000, 0.6000,
#         0.4000, 0.3500, 0.7000], device='cuda:0')
#
# Epoch 4 Loss: 0.7425
#
# Val Epoch 4 Metrics:
# F1 (macro): 0.32356387759692723
# F1 (micro): 0.4105960264900662
# Thresholds: tensor([0.9000, 0.8500, 0.6000, 0.4500, 0.4500, 0.2000, 0.4500, 0.4000, 0.8500,
#         0.5500, 0.2500, 0.7000], device='cuda:0')
#
# Epoch 5 Loss: 0.5879
#
# Val Epoch 5 Metrics:
# F1 (macro): 0.30790296524319205
# F1 (micro): 0.3628472222222222
# Thresholds: tensor([0.9000, 0.6500, 0.6500, 0.0500, 0.2000, 0.0500, 0.6000, 0.4000, 0.5000,
#         0.4500, 0.4500, 0.5000], device='cuda:0')
#
# Epoch 6 Loss: 0.4486
#
# Val Epoch 6 Metrics:
# F1 (macro): 0.3057249795592165
# F1 (micro): 0.389937106918239
# Thresholds: tensor([0.6000, 0.5500, 0.4500, 0.8500, 0.0500, 0.5000, 0.5000, 0.7000, 0.9000,
#         0.3500, 0.3500, 0.4500], device='cuda:0')
#
# Epoch 7 Loss: 0.3642
#
# Val Epoch 7 Metrics:
# F1 (macro): 0.30886345419271416
# F1 (micro): 0.3510737628384687
# Thresholds: tensor([0.8500, 0.3500, 0.2500, 0.3000, 0.1000, 0.0500, 0.6000, 0.6000, 0.9000,
#         0.6500, 0.6000, 0.1000], device='cuda:0')
#
# Epoch 8 Loss: 0.3010
#
# Val Epoch 8 Metrics:
# F1 (macro): 0.2913907594586456
# F1 (micro): 0.392018779342723
# Thresholds: tensor([0.7000, 0.6000, 0.2000, 0.2000, 0.1000, 0.5000, 0.4500, 0.6500, 0.2500,
#         0.6000, 0.4500, 0.2000], device='cuda:0')
#
# Epoch 9 Loss: 0.2335
#
# Val Epoch 9 Metrics:
# F1 (macro): 0.30506383624104294
# F1 (micro): 0.389010989010989
# Thresholds: tensor([0.9000, 0.3500, 0.1000, 0.0500, 0.0500, 0.0500, 0.2500, 0.7500, 0.7500,
#         0.2500, 0.3500, 0.2500], device='cuda:0')
#
# Epoch 10 Loss: 0.2017
#
# Val Epoch 10 Metrics:
# F1 (macro): 0.2765791397377851
# F1 (micro): 0.42105263157894735
# Thresholds: tensor([0.9000, 0.0500, 0.2000, 0.6500, 0.5000, 0.5000, 0.8500, 0.3500, 0.8000,
#         0.5000, 0.5000, 0.2000], device='cuda:0')
#
# Epoch 11 Loss: 0.1643
#
# Val Epoch 11 Metrics:
# F1 (macro): 0.2850484916994976
# F1 (micro): 0.387409200968523
# Thresholds: tensor([0.7000, 0.1000, 0.1500, 0.0500, 0.5000, 0.5000, 0.7000, 0.1000, 0.8000,
#         0.2000, 0.4500, 0.1000], device='cuda:0')
#
# Epoch 12 Loss: 0.1245
#
# Val Epoch 12 Metrics:
# F1 (macro): 0.290609885638658
# F1 (micro): 0.42048517520215634
# Thresholds: tensor([0.8500, 0.3500, 0.0500, 0.1500, 0.5000, 0.5000, 0.5000, 0.4000, 0.8000,
#         0.0500, 0.4000, 0.2000], device='cuda:0')

# %%
model3 = Model3(
    vocab_size=len(vocab.word2idx),
    embed_dim= 256,
    hidden_dim= 256,
    num_labels= 12
)

model3.to(device)

train(
    model= model3,
    train_loader= train_loader, 
    val_loader= val_loader, 
    lr= 3e-3,
    pos_weight= pos_weight, 
    epochs= 12,
    device= device
)
# Out:
# Epoch 1 Loss: 1.2445
#
# Val Epoch 1 Metrics:
# F1 (macro): 0.20748862825788641
# F1 (micro): 0.23352713178294573
# Thresholds: tensor([0.5000, 0.5000, 0.5500, 0.4500, 0.5000, 0.4000, 0.5000, 0.5000, 0.6500,
#         0.5000, 0.5000, 0.3500], device='cuda:0')
#
# Epoch 2 Loss: 1.1826
#
# Val Epoch 2 Metrics:
# F1 (macro): 0.25554898248630814
# F1 (micro): 0.316
# Thresholds: tensor([0.6000, 0.5500, 0.8000, 0.4500, 0.7500, 0.4500, 0.5000, 0.5000, 0.9000,
#         0.5500, 0.4500, 0.4000], device='cuda:0')
#
# Epoch 3 Loss: 1.0556
#
# Val Epoch 3 Metrics:
# F1 (macro): 0.2820821085987742
# F1 (micro): 0.33607169529499625
# Thresholds: tensor([0.7000, 0.6500, 0.8500, 0.5000, 0.7500, 0.5000, 0.5000, 0.6000, 0.7000,
#         0.5500, 0.5000, 0.3500], device='cuda:0')
#
# Epoch 4 Loss: 0.8684
#
# Val Epoch 4 Metrics:
# F1 (macro): 0.29372322532695777
# F1 (micro): 0.3911671924290221
# Thresholds: tensor([0.8500, 0.6500, 0.7500, 0.5000, 0.6500, 0.3500, 0.6000, 0.5500, 0.8000,
#         0.4500, 0.4500, 0.4000], device='cuda:0')
#
# Epoch 5 Loss: 0.6787
#
# Val Epoch 5 Metrics:
# F1 (macro): 0.30121474597337733
# F1 (micro): 0.3771106941838649
# Thresholds: tensor([0.9000, 0.3500, 0.6000, 0.2500, 0.6500, 0.0500, 0.7000, 0.7500, 0.9000,
#         0.3000, 0.5500, 0.3000], device='cuda:0')
#
# Epoch 6 Loss: 0.5478
#
# Val Epoch 6 Metrics:
# F1 (macro): 0.30085543648796753
# F1 (micro): 0.39236479321314954
# Thresholds: tensor([0.7500, 0.1000, 0.4500, 0.2500, 0.0500, 0.5000, 0.7000, 0.8000, 0.8500,
#         0.2000, 0.4500, 0.4500], device='cuda:0')
#
# Epoch 7 Loss: 0.4330
#
# Val Epoch 7 Metrics:
# F1 (macro): 0.2842098192236864
# F1 (micro): 0.3904856293359762
# Thresholds: tensor([0.8500, 0.8500, 0.3500, 0.2000, 0.0500, 0.5000, 0.4000, 0.6000, 0.7500,
#         0.4000, 0.4500, 0.1000], device='cuda:0')
#
# Epoch 8 Loss: 0.3530
#
# Val Epoch 8 Metrics:
# F1 (macro): 0.27397846213589333
# F1 (micro): 0.3710144927536232
# Thresholds: tensor([0.9000, 0.1000, 0.4500, 0.4000, 0.0500, 0.5000, 0.5000, 0.2500, 0.7000,
#         0.5500, 0.3000, 0.0500], device='cuda:0')
#
# Epoch 9 Loss: 0.2713
#
# Val Epoch 9 Metrics:
# F1 (macro): 0.27703905570331366
# F1 (micro): 0.39035591274397247
# Thresholds: tensor([0.4500, 0.7000, 0.7500, 0.5500, 0.3000, 0.5000, 0.6000, 0.4500, 0.7000,
#         0.1500, 0.3500, 0.1000], device='cuda:0')
#
# Epoch 10 Loss: 0.2198
#
# Val Epoch 10 Metrics:
# F1 (macro): 0.2805571504658155
# F1 (micro): 0.37566702241195304
# Thresholds: tensor([0.7500, 0.2500, 0.4500, 0.4500, 0.6000, 0.5000, 0.3500, 0.8500, 0.4000,
#         0.2000, 0.2500, 0.0500], device='cuda:0')
#
# Epoch 11 Loss: 0.1858
#
# Val Epoch 11 Metrics:
# F1 (macro): 0.26540145615147454
# F1 (micro): 0.34576271186440677
# Thresholds: tensor([0.9000, 0.7000, 0.1500, 0.1000, 0.1500, 0.5000, 0.9000, 0.0500, 0.8500,
#         0.2500, 0.5000, 0.0500], device='cuda:0')
#
# Epoch 12 Loss: 0.1602
#
# Val Epoch 12 Metrics:
# F1 (macro): 0.2724434112034918
# F1 (micro): 0.3479887745556595
# Thresholds: tensor([0.7500, 0.8000, 0.7500, 0.0500, 0.0500, 0.5000, 0.0500, 0.1000, 0.3000,
#         0.1500, 0.1000, 0.0500], device='cuda:0')

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model4 = Model4(
    vocab_size=len(vocab.word2idx),
    embed_dim= 128,
    hidden_dim= 128,
    num_labels= 12
)

model4.to(device)

train(
    model= model4, 
    train_loader= train_loader, 
    val_loader= val_loader, 
    lr= 2e-3,
    pos_weight= pos_weight, 
    epochs= 25,
    device= device
)
# Out:
# Epoch 1 Loss: 1.2524
#
# Val Epoch 1 Metrics:
# F1 (macro): 0.17908535460599495
# F1 (micro): 0.19930555555555557
# Thresholds: tensor([0.4000, 0.4500, 0.5000, 0.0500, 0.0500, 0.4500, 0.5000, 0.5000, 0.5500,
#         0.5000, 0.0500, 0.0500], device='cuda:0')
#
# Epoch 2 Loss: 1.2558
#
# Val Epoch 2 Metrics:
# F1 (macro): 0.231194124510635
# F1 (micro): 0.26832018038331457
# Thresholds: tensor([0.4500, 0.4500, 0.4000, 0.4500, 0.6500, 0.5500, 0.5000, 0.4000, 0.5500,
#         0.5000, 0.4500, 0.5500], device='cuda:0')
#
# Epoch 3 Loss: 1.1539
#
# Val Epoch 3 Metrics:
# F1 (macro): 0.24518183770041332
# F1 (micro): 0.2619047619047619
# Thresholds: tensor([0.1500, 0.6000, 0.5000, 0.5000, 0.8000, 0.6000, 0.6000, 0.0500, 0.6000,
#         0.6500, 0.5500, 0.4000], device='cuda:0')
#
# Epoch 4 Loss: 1.0936
#
# Val Epoch 4 Metrics:
# F1 (macro): 0.25290554680277905
# F1 (micro): 0.3035019455252918
# Thresholds: tensor([0.6500, 0.6000, 0.6500, 0.3500, 0.5000, 0.6000, 0.4500, 0.4000, 0.6500,
#         0.6000, 0.4500, 0.4500], device='cuda:0')
#
# Epoch 5 Loss: 0.9613
#
# Val Epoch 5 Metrics:
# F1 (macro): 0.26688652939603036
# F1 (micro): 0.3288888888888889
# Thresholds: tensor([0.8000, 0.6500, 0.1000, 0.3500, 0.7000, 0.1000, 0.5000, 0.3000, 0.4500,
#         0.5000, 0.3500, 0.5000], device='cuda:0')
#
# Epoch 6 Loss: 0.8446
#
# Val Epoch 6 Metrics:
# F1 (macro): 0.2662957759582763
# F1 (micro): 0.2923636363636364
# Thresholds: tensor([0.8500, 0.8000, 0.6000, 0.4000, 0.8500, 0.1500, 0.4000, 0.4500, 0.7000,
#         0.6500, 0.6500, 0.4000], device='cuda:0')
#
# Epoch 7 Loss: 0.7477
#
# Val Epoch 7 Metrics:
# F1 (macro): 0.24890467326750232
# F1 (micro): 0.32674772036474165
# Thresholds: tensor([0.8500, 0.9000, 0.3500, 0.4000, 0.5500, 0.0500, 0.2000, 0.4500, 0.5500,
#         0.5000, 0.4500, 0.6000], device='cuda:0')
#
# Epoch 8 Loss: 0.6615
#
# Val Epoch 8 Metrics:
# F1 (macro): 0.25311619448761846
# F1 (micro): 0.32801822323462415
# Thresholds: tensor([0.8500, 0.8500, 0.4500, 0.4000, 0.6500, 0.0500, 0.6000, 0.4500, 0.7000,
#         0.6000, 0.5000, 0.2000], device='cuda:0')
#
# Epoch 9 Loss: 0.6198
#
# Val Epoch 9 Metrics:
# F1 (macro): 0.2630222940728146
# F1 (micro): 0.34831460674157305
# Thresholds: tensor([0.7500, 0.8000, 0.0500, 0.3500, 0.4500, 0.5000, 0.5000, 0.4000, 0.8500,
#         0.6500, 0.6000, 0.3500], device='cuda:0')
#
# Epoch 10 Loss: 0.5821
#
# Val Epoch 10 Metrics:
# F1 (macro): 0.25730505857377534
# F1 (micro): 0.33519553072625696
# Thresholds: tensor([0.8500, 0.9000, 0.0500, 0.3000, 0.9000, 0.5000, 0.4000, 0.3500, 0.5000,
#         0.5500, 0.6000, 0.4000], device='cuda:0')
#
# Epoch 11 Loss: 0.5003
#
# Val Epoch 11 Metrics:
# F1 (macro): 0.2482906135133364
# F1 (micro): 0.3302180685358255
# Thresholds: tensor([0.8000, 0.7500, 0.1000, 0.3000, 0.5000, 0.5000, 0.0500, 0.3000, 0.5500,
#         0.6000, 0.5500, 0.1500], device='cuda:0')
#
# Epoch 12 Loss: 0.4620
#
# Val Epoch 12 Metrics:
# F1 (macro): 0.2537198831525047
# F1 (micro): 0.34654377880184334
# Thresholds: tensor([0.7500, 0.9000, 0.1500, 0.4000, 0.1500, 0.5000, 0.5000, 0.5500, 0.7500,
#         0.7500, 0.5000, 0.0500], device='cuda:0')
#
# Epoch 13 Loss: 0.3984
#
# Val Epoch 13 Metrics:
# F1 (macro): 0.25085876212652686
# F1 (micro): 0.3553299492385787
# Thresholds: tensor([0.6000, 0.8000, 0.0500, 0.2500, 0.0500, 0.5000, 0.3000, 0.4000, 0.2500,
#         0.4000, 0.5000, 0.0500], device='cuda:0')
#
# Epoch 14 Loss: 0.3581
#
# Val Epoch 14 Metrics:
# F1 (macro): 0.23985390997786282
# F1 (micro): 0.3404605263157895
# Thresholds: tensor([0.8000, 0.4500, 0.5000, 0.1500, 0.1000, 0.5000, 0.0500, 0.2500, 0.5500,
#         0.5000, 0.3500, 0.0500], device='cuda:0')
#
# Epoch 15 Loss: 0.3360
#
# Val Epoch 15 Metrics:
# F1 (macro): 0.23168924275580796
# F1 (micro): 0.3235294117647059
# Thresholds: tensor([0.4500, 0.6500, 0.0500, 0.1000, 0.5000, 0.5000, 0.5500, 0.6000, 0.7000,
#         0.5500, 0.6000, 0.1000], device='cuda:0')
#
# Epoch 16 Loss: 0.3619
#
# Val Epoch 16 Metrics:
# F1 (macro): 0.24236376076092156
# F1 (micro): 0.328086164043082
# Thresholds: tensor([0.9000, 0.2500, 0.1000, 0.5000, 0.4000, 0.5000, 0.7500, 0.1000, 0.4500,
#         0.5500, 0.3500, 0.0500], device='cuda:0')
#
# Epoch 17 Loss: 0.3339
#
# Val Epoch 17 Metrics:
# F1 (macro): 0.2538878735441916
# F1 (micro): 0.3558792924037461
# Thresholds: tensor([0.6000, 0.7000, 0.4000, 0.0500, 0.3500, 0.5000, 0.7000, 0.7000, 0.8000,
#         0.6500, 0.4000, 0.1000], device='cuda:0')
#
# Epoch 18 Loss: 0.2871
#
# Val Epoch 18 Metrics:
# F1 (macro): 0.2519724137587715
# F1 (micro): 0.34332425068119893
# Thresholds: tensor([0.9000, 0.1500, 0.1000, 0.1000, 0.1500, 0.5000, 0.2000, 0.1000, 0.8500,
#         0.6000, 0.5000, 0.1000], device='cuda:0')
#
# Epoch 19 Loss: 0.2727
#
# Val Epoch 19 Metrics:
# F1 (macro): 0.24755389121773652
# F1 (micro): 0.3309982486865149
# Thresholds: tensor([0.5000, 0.5500, 0.2500, 0.4500, 0.1500, 0.5000, 0.1500, 0.3000, 0.8500,
#         0.7000, 0.1500, 0.0500], device='cuda:0')
#
# Epoch 20 Loss: 0.2854
#
# Val Epoch 20 Metrics:
# F1 (macro): 0.23819594775657804
# F1 (micro): 0.3359442993907746
# Thresholds: tensor([0.1500, 0.6000, 0.0500, 0.0500, 0.0500, 0.5000, 0.3000, 0.5500, 0.8000,
#         0.5500, 0.1500, 0.0500], device='cuda:0')
#
# Epoch 21 Loss: 0.2348
#
# Val Epoch 21 Metrics:
# F1 (macro): 0.2462243628461681
# F1 (micro): 0.333692142088267
# Thresholds: tensor([0.7000, 0.6500, 0.0500, 0.0500, 0.2000, 0.5000, 0.4500, 0.6000, 0.5500,
#         0.4500, 0.5500, 0.1500], device='cuda:0')
#
# Epoch 22 Loss: 0.2057
#
# Val Epoch 22 Metrics:
# F1 (macro): 0.2231442989420623
# F1 (micro): 0.3196172248803828
# Thresholds: tensor([0.9000, 0.3000, 0.5000, 0.6500, 0.1000, 0.5000, 0.3500, 0.0500, 0.4500,
#         0.3500, 0.2000, 0.1500], device='cuda:0')
#
# Epoch 23 Loss: 0.1947
#
# Val Epoch 23 Metrics:
# F1 (macro): 0.21851125382214795
# F1 (micro): 0.3140877598152425
# Thresholds: tensor([0.7000, 0.1000, 0.5000, 0.2000, 0.5000, 0.5000, 0.6500, 0.8000, 0.1000,
#         0.6000, 0.4500, 0.0500], device='cuda:0')
#
# Epoch 24 Loss: 0.1656
#
# Val Epoch 24 Metrics:
# F1 (macro): 0.24494120728734273
# F1 (micro): 0.3493975903614458
# Thresholds: tensor([0.9000, 0.3500, 0.0500, 0.0500, 0.5000, 0.5000, 0.6000, 0.8000, 0.1500,
#         0.4500, 0.4000, 0.1000], device='cuda:0')
#
# Epoch 25 Loss: 0.1556
#
# Val Epoch 25 Metrics:
# F1 (macro): 0.2203168620458156
# F1 (micro): 0.35141509433962265
# Thresholds: tensor([0.7000, 0.1500, 0.5000, 0.0500, 0.5000, 0.5000, 0.7000, 0.8000, 0.0500,
#         0.5000, 0.2000, 0.0500], device='cuda:0')

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model5 = Model5(
    vocab_size=len(vocab.word2idx),
    embed_dim= 256,
    hidden_dim= 128,
    num_labels= 12
)

model5.to(device)

train(
    model= model5, 
    train_loader= train_loader, 
    val_loader= val_loader, 
    lr= 2e-3,
    pos_weight= pos_weight, 
    epochs= 25,
    device= device
)
# Out:
# Epoch 1 Loss: 1.2437
#
# Val Epoch 1 Metrics:
# F1 (macro): 0.19802010278592677
# F1 (micro): 0.22845849802371543
# Thresholds: tensor([0.5000, 0.5000, 0.5000, 0.5500, 0.5000, 0.4000, 0.4500, 0.4500, 0.4500,
#         0.5000, 0.5000, 0.4000], device='cuda:0')
#
# Epoch 2 Loss: 1.2300
#
# Val Epoch 2 Metrics:
# F1 (macro): 0.23207925425987366
# F1 (micro): 0.24048096192384769
# Thresholds: tensor([0.5500, 0.4500, 0.4000, 0.4500, 0.6000, 0.5000, 0.4500, 0.5000, 0.4500,
#         0.5000, 0.4500, 0.5000], device='cuda:0')
#
# Epoch 3 Loss: 1.1610
#
# Val Epoch 3 Metrics:
# F1 (macro): 0.24499931988987056
# F1 (micro): 0.28820960698689957
# Thresholds: tensor([0.6000, 0.6000, 0.5500, 0.5000, 0.5500, 0.5000, 0.4000, 0.5000, 0.4500,
#         0.6000, 0.5000, 0.4500], device='cuda:0')
#
# Epoch 4 Loss: 1.0179
#
# Val Epoch 4 Metrics:
# F1 (macro): 0.24312981694004468
# F1 (micro): 0.31842105263157894
# Thresholds: tensor([0.8000, 0.6000, 0.6500, 0.4000, 0.8500, 0.7000, 0.4500, 0.3500, 0.7500,
#         0.5500, 0.4500, 0.4000], device='cuda:0')
#
# Epoch 5 Loss: 0.8626
#
# Val Epoch 5 Metrics:
# F1 (macro): 0.24124842568588098
# F1 (micro): 0.27497062279670975
# Thresholds: tensor([0.8500, 0.6500, 0.3500, 0.3500, 0.7500, 0.2000, 0.3500, 0.3500, 0.1500,
#         0.6000, 0.4500, 0.4500], device='cuda:0')
#
# Epoch 6 Loss: 0.7298
#
# Val Epoch 6 Metrics:
# F1 (macro): 0.26545093225167365
# F1 (micro): 0.2962962962962963
# Thresholds: tensor([0.5500, 0.2500, 0.2000, 0.2000, 0.5000, 0.0500, 0.4000, 0.3000, 0.1500,
#         0.6000, 0.4500, 0.6000], device='cuda:0')
#
# Epoch 7 Loss: 0.6227
#
# Val Epoch 7 Metrics:
# F1 (macro): 0.2519496207805999
# F1 (micro): 0.32971506105834464
# Thresholds: tensor([0.6500, 0.3000, 0.4000, 0.6000, 0.4500, 0.5000, 0.4500, 0.2500, 0.1000,
#         0.5000, 0.3500, 0.1000], device='cuda:0')
#
# Epoch 8 Loss: 0.5159
#
# Val Epoch 8 Metrics:
# F1 (macro): 0.2609395387775891
# F1 (micro): 0.34011391375101707
# Thresholds: tensor([0.9000, 0.5500, 0.0500, 0.1500, 0.0500, 0.5000, 0.4500, 0.0500, 0.3500,
#         0.5500, 0.3500, 0.5500], device='cuda:0')
#
# Epoch 9 Loss: 0.4600
#
# Val Epoch 9 Metrics:
# F1 (macro): 0.26072145330754076
# F1 (micro): 0.3631578947368421
# Thresholds: tensor([0.6000, 0.4500, 0.3500, 0.2500, 0.7000, 0.5000, 0.4500, 0.4000, 0.6000,
#         0.5500, 0.5000, 0.0500], device='cuda:0')
#
# Epoch 10 Loss: 0.3974
#
# Val Epoch 10 Metrics:
# F1 (macro): 0.2595162535077991
# F1 (micro): 0.3176954732510288
# Thresholds: tensor([0.9000, 0.7500, 0.0500, 0.0500, 0.1000, 0.0500, 0.6000, 0.3000, 0.8000,
#         0.5000, 0.3500, 0.1500], device='cuda:0')
#
# Epoch 11 Loss: 0.3337
#
# Val Epoch 11 Metrics:
# F1 (macro): 0.23942477599245512
# F1 (micro): 0.3288364249578415
# Thresholds: tensor([0.4500, 0.8000, 0.2000, 0.0500, 0.0500, 0.5000, 0.1500, 0.2000, 0.1000,
#         0.5500, 0.3500, 0.1000], device='cuda:0')
#
# Epoch 12 Loss: 0.3325
#
# Val Epoch 12 Metrics:
# F1 (macro): 0.2872369706576207
# F1 (micro): 0.39059304703476483
# Thresholds: tensor([0.3000, 0.7000, 0.1000, 0.1000, 0.7500, 0.5000, 0.3500, 0.4500, 0.4000,
#         0.5500, 0.2000, 0.1000], device='cuda:0')
#
# Epoch 13 Loss: 0.2476
#
# Val Epoch 13 Metrics:
# F1 (macro): 0.26397031589343317
# F1 (micro): 0.3486901535682023
# Thresholds: tensor([0.7000, 0.3500, 0.1500, 0.0500, 0.8500, 0.5000, 0.3000, 0.0500, 0.3500,
#         0.2000, 0.1000, 0.0500], device='cuda:0')
#
# Epoch 14 Loss: 0.1917
#
# Val Epoch 14 Metrics:
# F1 (macro): 0.2557410585367372
# F1 (micro): 0.3506787330316742
# Thresholds: tensor([0.3500, 0.0500, 0.2500, 0.0500, 0.1000, 0.5000, 0.7500, 0.0500, 0.1000,
#         0.5500, 0.3000, 0.0500], device='cuda:0')
#
# Epoch 15 Loss: 0.1743
#
# Val Epoch 15 Metrics:
# F1 (macro): 0.2710039278917617
# F1 (micro): 0.3815165876777251
# Thresholds: tensor([0.6500, 0.3500, 0.2000, 0.1500, 0.0500, 0.5000, 0.3500, 0.4500, 0.4500,
#         0.6000, 0.2500, 0.0500], device='cuda:0')
#
# Epoch 16 Loss: 0.1667
#
# Val Epoch 16 Metrics:
# F1 (macro): 0.2771466655103772
# F1 (micro): 0.3477272727272727
# Thresholds: tensor([0.0500, 0.9000, 0.1000, 0.0500, 0.0500, 0.5000, 0.4000, 0.4000, 0.5000,
#         0.6500, 0.3000, 0.1000], device='cuda:0')
#
# Epoch 17 Loss: 0.1545
#
# Val Epoch 17 Metrics:
# F1 (macro): 0.26509447435320005
# F1 (micro): 0.3689776733254994
# Thresholds: tensor([0.3000, 0.2500, 0.6500, 0.0500, 0.2000, 0.5000, 0.2500, 0.2000, 0.4500,
#         0.2500, 0.6000, 0.0500], device='cuda:0')
#
# Epoch 18 Loss: 0.1704
#
# Val Epoch 18 Metrics:
# F1 (macro): 0.27997797347005754
# F1 (micro): 0.3742255266418835
# Thresholds: tensor([0.1500, 0.0500, 0.2500, 0.1500, 0.1000, 0.5000, 0.1500, 0.0500, 0.4000,
#         0.4500, 0.7500, 0.6500], device='cuda:0')
#
# Epoch 19 Loss: 0.1599
#
# Val Epoch 19 Metrics:
# F1 (macro): 0.2598157747838709
# F1 (micro): 0.34442270058708413
# Thresholds: tensor([0.6500, 0.0500, 0.4000, 0.1000, 0.2500, 0.5000, 0.1000, 0.0500, 0.0500,
#         0.1500, 0.3000, 0.0500], device='cuda:0')
#
# Epoch 20 Loss: 0.1616
#
# Val Epoch 20 Metrics:
# F1 (macro): 0.27034708924966294
# F1 (micro): 0.39848675914249687
# Thresholds: tensor([0.3000, 0.3000, 0.0500, 0.0500, 0.3000, 0.5000, 0.2500, 0.5500, 0.1000,
#         0.1000, 0.7500, 0.0500], device='cuda:0')
#
# Epoch 21 Loss: 0.1369
#
# Val Epoch 21 Metrics:
# F1 (macro): 0.26808305280837286
# F1 (micro): 0.3632183908045977
# Thresholds: tensor([0.2000, 0.1000, 0.3000, 0.0500, 0.0500, 0.5000, 0.1000, 0.5000, 0.1000,
#         0.3500, 0.7000, 0.0500], device='cuda:0')
#
# Epoch 22 Loss: 0.1167
#
# Val Epoch 22 Metrics:
# F1 (macro): 0.24308305577539382
# F1 (micro): 0.34932349323493234
# Thresholds: tensor([0.9000, 0.1000, 0.1500, 0.2500, 0.5000, 0.5000, 0.2000, 0.1000, 0.0500,
#         0.2500, 0.7000, 0.0500], device='cuda:0')
#
# Epoch 23 Loss: 0.0766
#
# Val Epoch 23 Metrics:
# F1 (macro): 0.2504899260482845
# F1 (micro): 0.37824474660074164
# Thresholds: tensor([0.9000, 0.1000, 0.3000, 0.5000, 0.0500, 0.5000, 0.1000, 0.0500, 0.0500,
#         0.1000, 0.4500, 0.0500], device='cuda:0')
#
# Epoch 24 Loss: 0.0635
#
# Val Epoch 24 Metrics:
# F1 (macro): 0.24649993315046337
# F1 (micro): 0.3858695652173913
# Thresholds: tensor([0.9000, 0.2500, 0.0500, 0.1000, 0.2000, 0.5000, 0.2500, 0.5000, 0.3500,
#         0.1000, 0.6500, 0.0500], device='cuda:0')
#
# Epoch 25 Loss: 0.0585
#
# Val Epoch 25 Metrics:
# F1 (macro): 0.25778665189048705
# F1 (micro): 0.39847715736040606
# Thresholds: tensor([0.9000, 0.0500, 0.1000, 0.3500, 0.5000, 0.5000, 0.1000, 0.6500, 0.0500,
#         0.2000, 0.1500, 0.0500], device='cuda:0')

# %%
for i, model in enumerate([model1, model2, model3, model4, model5]):
    evaluate(model, test_loader, device, name=f"Model-{i+1}")
# Out:
# Model-1 Metrics:
# F1 (macro): 0.21508681328283244
# F1 (micro): 0.3359639233370913
# Thresholds: tensor([0.8000, 0.4500, 0.7000, 0.4500, 0.1500, 0.5000, 0.4500, 0.1000, 0.1500,
#         0.3000, 0.3000, 0.5000], device='cuda:0')
#
# Model-2 Metrics:
# F1 (macro): 0.2497545963047738
# F1 (micro): 0.35667107001321
# Thresholds: tensor([0.8500, 0.3500, 0.0500, 0.1500, 0.5000, 0.5000, 0.5000, 0.4000, 0.8000,
#         0.0500, 0.4000, 0.2000], device='cuda:0')
#
# Model-3 Metrics:
# F1 (macro): 0.23656962618601388
# F1 (micro): 0.3492063492063492
# Thresholds: tensor([0.7500, 0.8000, 0.7500, 0.0500, 0.0500, 0.5000, 0.0500, 0.1000, 0.3000,
#         0.1500, 0.1000, 0.0500], device='cuda:0')
#
# Model-4 Metrics:
# F1 (macro): 0.16172245326674686
# F1 (micro): 0.28438228438228436
# Thresholds: tensor([0.7000, 0.1500, 0.5000, 0.0500, 0.5000, 0.5000, 0.7000, 0.8000, 0.0500,
#         0.5000, 0.2000, 0.0500], device='cuda:0')
#
# Model-5 Metrics:
# F1 (macro): 0.21306209304813814
# F1 (micro): 0.3522167487684729
# Thresholds: tensor([0.9000, 0.0500, 0.1000, 0.3500, 0.5000, 0.5000, 0.1000, 0.6500, 0.0500,
#         0.2000, 0.1500, 0.0500], device='cuda:0')

# %%
import matplotlib.pyplot as plt

models    = ["M1\nMean Pool", "M2\nMax+Mean", "M3\nAttention", "M4\nHierarchical", "M5\nTransitions"]
macro_f1  = [0.2151, 0.2498, 0.2366, 0.1617, 0.2131]
micro_f1  = [0.3360, 0.3567, 0.3492, 0.2844, 0.3522]

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(13, 5))

for ax, vals, title, color in [
    (ax1, macro_f1, "Macro F1 — Phase I", "#2c7bb6"),
    (ax2, micro_f1, "Micro F1 — Phase I", "#1a9641"),
]:
    bars = ax.bar(models, vals, color=color, width=0.5, edgecolor="white")
    ax.set_ylim(0, max(vals) * 1.25)
    ax.set_title(title, fontsize=12)
    ax.axhline(max(vals), color="orange", linestyle="--", linewidth=1, alpha=0.7)
    for bar, v in zip(bars, vals):
        ax.text(bar.get_x() + bar.get_width() / 2, v + 0.004, f"{v:.3f}", ha="center", fontsize=9)

plt.tight_layout()
plt.show()
